# %% [markdown]
# ### Importing Libraries

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.dates as mdates
from tensorflow.random import set_seed
from tensorflow.keras.layers import Bidirectional
import warnings
warnings.filterwarnings('ignore')
# Out:
# WARNING:tensorflow:From C:\Users\achan\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ### Data Collection

# %%
# Set random seeds for reproducibility
np.random.seed(42)
set_seed(42)

# Download stock data
ticker_symbol = 'GOOGL'
ticker_data = yf.Ticker(ticker_symbol)
df = ticker_data.history(period='1d', start='2015-11-01', end='2023-11-25')
df.reset_index(inplace=True)
df = df[['Date', 'Close']]
df
# Out:
#                           Date       Close
# 0    2015-11-02 00:00:00-05:00   37.387001
# 1    2015-11-03 00:00:00-05:00   37.441002
# 2    2015-11-04 00:00:00-05:00   37.765499
# 3    2015-11-05 00:00:00-05:00   38.033501
# 4    2015-11-06 00:00:00-05:00   38.080002
# ...                        ...         ...
# 2025 2023-11-17 00:00:00-05:00  135.309998
# 2026 2023-11-20 00:00:00-05:00  136.250000
# 2027 2023-11-21 00:00:00-05:00  136.970001
# 2028 2023-11-22 00:00:00-05:00  138.490005
# 2029 2023-11-24 00:00:00-05:00  136.690002
#
# [2030 rows x 2 columns]

# %% [markdown]
# ### Data Preprocessing

# %%
# Data is scaled to values between 0 and 1
scaler = MinMaxScaler(feature_range=(0, 1))
training_data_len = int(np.ceil(len(df) * 0.8))
scaler.fit(df['Close'].values[:training_data_len].reshape(-1, 1))
scaled_data = scaler.transform(df['Close'].values.reshape(-1, 1))

# %%
# Create the training and testing data set
train_data = scaled_data[0:training_data_len, :]
test_data = scaled_data[training_data_len - 60:, :]

# %%
# Split the data into x_train, y_train, x_test, and y_test data sets
x_train, y_train = [], []
x_test, y_test = [], df['Close'][training_data_len:].values
for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])

for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i, 0])

# %%
# Convert to numpy arrays for the LSTM model
x_train, y_train = np.array(x_train), np.array(y_train)
x_test, y_test = np.array(x_test), np.array(y_test)

# %%
# Reshape the data into the shape accepted by the LSTM
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %% [markdown]
# ### Build the Bidirectional LSTM Model

# %%
# Build the LSTM Model with bidirectional LSTM layers
model = Sequential([
    Bidirectional(LSTM(units=50, return_sequences=True), input_shape=(x_train.shape[1], 1)),
    Dropout(0.2),
    Bidirectional(LSTM(units=50, return_sequences=False)),
    Dropout(0.2),
    Dense(units=25),
    Dense(units=1)
])

# Compile the model with a mean squared error loss function and the adam optimizer
model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# WARNING:tensorflow:From C:\Users\achan\anaconda3\Lib\site-packages\keras\src\layers\rnn\lstm.py:148: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\achan\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# Train the model with early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
history = model.fit(x_train, y_train, batch_size=32, epochs=100, 
                    validation_data=(x_test, y_test), callbacks=[early_stopping], verbose=1)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\achan\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 49/49 [==============================] - 6s 45ms/step - loss: 0.0091 - val_loss: 12675.4795
# Epoch 2/100
# 49/49 [==============================] - 1s 26ms/step - loss: 0.0023 - val_loss: 12678.8145
# Epoch 3/100
# 49/49 [==============================] - 1s 27ms/step - loss: 0.0017 - val_loss: 12683.5566
# Epoch 4/100
# 49/49 [==============================] - 1s 28ms/step - loss: 0.0015 - val_loss: 12677.1992
# Epoch 5/100
# 49/49 [==============================] - 1s 30ms/step - loss: 0.0013 - val_loss: 12676.6846
# Epoch 6/100
# 49/49 [==============================] - 2s 31ms/step - loss: 0.0014 - val_loss: 12681.3193
# Epoch 7/100
# 49/49 [==============================] - 1s 25ms/step - loss: 0.0012 - val_loss: 12684.1621
# Epoch 8/100
# 49/49 [==============================] - 1s 21ms/step - loss: 0.0013 - val_loss: 12680.6738
# Epoch 9/100
# 49/49 [==============================] - 1s 21ms/step - loss: 0.0011 - val_loss: 12680.8535
# Epoch 10/100
# 49/49 [==============================] - 1s 21ms/step - loss: 9.9101e-04 - val_loss: 12675.6846
# Epoch 11/100
# 49/49 [==============================] - 1s 23ms/step - loss: 0.0013 - val_loss: 12683.7344

# %% [markdown]
# ### Evaluate the Model and Print RMSE

# %%
# Predict on training set and test set
train_predictions = model.predict(x_train)
train_predictions = scaler.inverse_transform(train_predictions)
test_predictions = model.predict(x_test)
test_predictions = scaler.inverse_transform(test_predictions)
# Out:
# 49/49 [==============================] - 1s 7ms/step
# 13/13 [==============================] - 0s 7ms/step

# %%
# Calculate RMSE performance metrics
train_rmse = np.sqrt(mean_squared_error(y_train, train_predictions))
test_rmse = np.sqrt(mean_squared_error(y_test, test_predictions))
print(f"Train RMSE: {train_rmse}, Test RMSE: {test_rmse}")
# Out:
# Train RMSE: 76.86916664400493, Test RMSE: 9.4882112671059

# %% [markdown]
# ### Visualize the Training Data and Predictions

# %%
# Visualize the training data and predictions
df['Date'] = pd.to_datetime(df['Date'])
adjusted_train_dates = df['Date'][60:training_data_len]

plt.figure(figsize=(16, 8))
plt.title('Train Dataset')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

plt.plot(df['Date'][:training_data_len], df['Close'][:training_data_len], label='Actual Values (Train)', color='blue')
plt.plot(adjusted_train_dates, train_predictions, label='Predicted Values (Train)', color='green')

plt.xticks(rotation=45)
plt.legend(loc='lower right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Forecasting the Next 365 Days

# %%
# Forecast the next 365 days
last_60_days = scaled_data[-60:]
predicted_prices = []

for i in range(365):
    X_pred_scaled = last_60_days.reshape(1, -1, 1)
    pred_price_scaled = model.predict(X_pred_scaled)
    predicted_prices.append(pred_price_scaled[0, 0])
    last_60_days = np.append(last_60_days, pred_price_scaled)[1:].reshape(-1, 1)

predicted_prices = scaler.inverse_transform(np.array(predicted_prices).reshape(-1, 1))

last_date = pd.to_datetime(df['Date'].iloc[-1])
prediction_dates = [last_date + pd.Timedelta(days=x + 1) for x in range(365)]
predicted_prices = predicted_prices.flatten()
s
for i in range(len(prediction_dates)):
    print(f"Predicted closing price for {prediction_dates[i].date()}: ${predicted_prices[i]:.2f}")
# Out:
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# Predicted closing price for 2023-11-25: $139.85
# Predicted closing price for 2023-11-26: $140.19
# Predicted closing price for 2023-11-27: $140.54
# Predicted closing price for 2023-11-28: $140.86
# Predicted closing price for 2023-11-29: $141.21
# Predicted closing price for 2023-11-30: $141.50
# Predicted closing price for 2023-12-01: $141.70
# Predicted closing price for 2023-12-02: $141.84
# Predicted closing price for 2023-12-03: $142.01
# Predicted closing price for 2023-12-04: $142.07
# Predicted closing price for 2023-12-05: $142.03
# Predicted closing price for 2023-12-06: $141.97
# Predicted closing price for 2023-12-07: $141.84
# Predicted closing price for 2023-12-08: $141.70
# Predicted closing price for 2023-12-09: $141.77
# Predicted closing price for 2023-12-10: $142.00
# Predicted closing price for 2023-12-11: $142.27
# Predicted closing price for 2023-12-12: $142.54
# Predicted closing price for 2023-12-13: $142.95
# Predicted closing price for 2023-12-14: $143.30
# Predicted closing price for 2023-12-15: $143.59
# Predicted closing price for 2023-12-16: $143.97
# Predicted closing price for 2023-12-17: $144.20
# Predicted closing price for 2023-12-18: $144.52
# Predicted closing price for 2023-12-19: $144.70
# Predicted closing price for 2023-12-20: $144.86
# Predicted closing price for 2023-12-21: $144.88
# Predicted closing price for 2023-12-22: $144.81
# Predicted closing price for 2023-12-23: $144.70
# Predicted closing price for 2023-12-24: $144.42
# Predicted closing price for 2023-12-25: $144.16
# Predicted closing price for 2023-12-26: $143.90
# Predicted closing price for 2023-12-27: $143.49
# Predicted closing price for 2023-12-28: $142.98
# Predicted closing price for 2023-12-29: $142.50
# Predicted closing price for 2023-12-30: $141.97
# Predicted closing price for 2023-12-31: $141.49
# Predicted closing price for 2024-01-01: $140.94
# Predicted closing price for 2024-01-02: $140.31
# Predicted closing price for 2024-01-03: $140.33
# Predicted closing price for 2024-01-04: $140.57
# Predicted closing price for 2024-01-05: $140.90
# Predicted closing price for 2024-01-06: $141.19
# Predicted closing price for 2024-01-07: $141.56
# Predicted closing price for 2024-01-08: $141.89
# Predicted closing price for 2024-01-09: $142.23
# Predicted closing price for 2024-01-10: $142.54
# Predicted closing price for 2024-01-11: $142.85
# Predicted closing price for 2024-01-12: $143.17
# Predicted closing price for 2024-01-13: $143.49
# Predicted closing price for 2024-01-14: $143.94
# Predicted closing price for 2024-01-15: $144.32
# Predicted closing price for 2024-01-16: $144.76
# Predicted closing price for 2024-01-17: $145.17
# Predicted closing price for 2024-01-18: $145.56
# Predicted closing price for 2024-01-19: $145.87
# Predicted closing price for 2024-01-20: $146.27
# Predicted closing price for 2024-01-21: $146.66
# Predicted closing price for 2024-01-22: $147.03
# Predicted closing price for 2024-01-23: $147.35
# Predicted closing price for 2024-01-24: $147.76
# Predicted closing price for 2024-01-25: $148.04
# Predicted closing price for 2024-01-26: $148.30
# Predicted closing price for 2024-01-27: $148.55
# Predicted closing price for 2024-01-28: $148.78
# Predicted closing price for 2024-01-29: $148.99
# Predicted closing price for 2024-01-30: $149.18
# Predicted closing price for 2024-01-31: $149.37
# Predicted closing price for 2024-02-01: $149.54
# Predicted closing price for 2024-02-02: $149.70
# Predicted closing price for 2024-02-03: $149.86
# Predicted closing price for 2024-02-04: $150.02
# Predicted closing price for 2024-02-05: $150.19
# Predicted closing price for 2024-02-06: $150.36
# Predicted closing price for 2024-02-07: $150.55
# Predicted closing price for 2024-02-08: $150.74
# Predicted closing price for 2024-02-09: $150.92
# Predicted closing price for 2024-02-10: $151.10
# Predicted closing price for 2024-02-11: $151.26
# Predicted closing price for 2024-02-12: $151.40
# Predicted closing price for 2024-02-13: $151.52
# Predicted closing price for 2024-02-14: $151.62
# Predicted closing price for 2024-02-15: $151.69
# Predicted closing price for 2024-02-16: $151.73
# Predicted closing price for 2024-02-17: $151.74
# Predicted closing price for 2024-02-18: $151.73
# Predicted closing price for 2024-02-19: $151.69
# Predicted closing price for 2024-02-20: $151.62
# Predicted closing price for 2024-02-21: $151.54
# Predicted closing price for 2024-02-22: $151.44
# Predicted closing price for 2024-02-23: $151.34
# Predicted closing price for 2024-02-24: $151.23
# Predicted closing price for 2024-02-25: $151.12
# Predicted closing price for 2024-02-26: $151.03
# Predicted closing price for 2024-02-27: $150.95
# Predicted closing price for 2024-02-28: $150.90
# Predicted closing price for 2024-02-29: $150.88
# Predicted closing price for 2024-03-01: $150.89
# Predicted closing price for 2024-03-02: $150.95
# Predicted closing price for 2024-03-03: $151.06
# Predicted closing price for 2024-03-04: $151.19
# Predicted closing price for 2024-03-05: $151.34
# Predicted closing price for 2024-03-06: $151.50
# Predicted closing price for 2024-03-07: $151.68
# Predicted closing price for 2024-03-08: $151.86
# Predicted closing price for 2024-03-09: $152.05
# Predicted closing price for 2024-03-10: $152.25
# Predicted closing price for 2024-03-11: $152.45
# Predicted closing price for 2024-03-12: $152.67
# Predicted closing price for 2024-03-13: $152.90
# Predicted closing price for 2024-03-14: $153.13
# Predicted closing price for 2024-03-15: $153.36
# Predicted closing price for 2024-03-16: $153.60
# Predicted closing price for 2024-03-17: $153.83
# Predicted closing price for 2024-03-18: $154.06
# Predicted closing price for 2024-03-19: $154.29
# Predicted closing price for 2024-03-20: $154.52
# Predicted closing price for 2024-03-21: $154.74
# Predicted closing price for 2024-03-22: $154.96
# Predicted closing price for 2024-03-23: $155.17
# Predicted closing price for 2024-03-24: $155.37
# Predicted closing price for 2024-03-25: $155.57
# Predicted closing price for 2024-03-26: $155.75
# Predicted closing price for 2024-03-27: $155.94
# Predicted closing price for 2024-03-28: $156.11
# Predicted closing price for 2024-03-29: $156.28
# Predicted closing price for 2024-03-30: $156.44
# Predicted closing price for 2024-03-31: $156.60
# Predicted closing price for 2024-04-01: $156.76
# Predicted closing price for 2024-04-02: $156.91
# Predicted closing price for 2024-04-03: $157.06
# Predicted closing price for 2024-04-04: $157.20
# Predicted closing price for 2024-04-05: $157.34
# Predicted closing price for 2024-04-06: $157.47
# Predicted closing price for 2024-04-07: $157.59
# Predicted closing price for 2024-04-08: $157.71
# Predicted closing price for 2024-04-09: $157.81
# Predicted closing price for 2024-04-10: $157.91
# Predicted closing price for 2024-04-11: $157.99
# Predicted closing price for 2024-04-12: $158.07
# Predicted closing price for 2024-04-13: $158.13
# Predicted closing price for 2024-04-14: $158.18
# Predicted closing price for 2024-04-15: $158.22
# Predicted closing price for 2024-04-16: $158.26
# Predicted closing price for 2024-04-17: $158.28
# Predicted closing price for 2024-04-18: $158.30
# Predicted closing price for 2024-04-19: $158.31
# Predicted closing price for 2024-04-20: $158.32
# Predicted closing price for 2024-04-21: $158.33
# Predicted closing price for 2024-04-22: $158.34
# Predicted closing price for 2024-04-23: $158.36
# Predicted closing price for 2024-04-24: $158.38
# Predicted closing price for 2024-04-25: $158.40
# Predicted closing price for 2024-04-26: $158.44
# Predicted closing price for 2024-04-27: $158.48
# Predicted closing price for 2024-04-28: $158.54
# Predicted closing price for 2024-04-29: $158.61
# Predicted closing price for 2024-04-30: $158.68
# Predicted closing price for 2024-05-01: $158.77
# Predicted closing price for 2024-05-02: $158.87
# Predicted closing price for 2024-05-03: $158.97
# Predicted closing price for 2024-05-04: $159.08
# Predicted closing price for 2024-05-05: $159.20
# Predicted closing price for 2024-05-06: $159.32
# Predicted closing price for 2024-05-07: $159.45
# Predicted closing price for 2024-05-08: $159.58
# Predicted closing price for 2024-05-09: $159.72
# Predicted closing price for 2024-05-10: $159.86
# Predicted closing price for 2024-05-11: $160.00
# Predicted closing price for 2024-05-12: $160.15
# Predicted closing price for 2024-05-13: $160.30
# Predicted closing price for 2024-05-14: $160.45
# Predicted closing price for 2024-05-15: $160.60
# Predicted closing price for 2024-05-16: $160.74
# Predicted closing price for 2024-05-17: $160.89
# Predicted closing price for 2024-05-18: $161.04
# Predicted closing price for 2024-05-19: $161.19
# Predicted closing price for 2024-05-20: $161.33
# Predicted closing price for 2024-05-21: $161.47
# Predicted closing price for 2024-05-22: $161.61
# Predicted closing price for 2024-05-23: $161.75
# Predicted closing price for 2024-05-24: $161.88
# Predicted closing price for 2024-05-25: $162.01
# Predicted closing price for 2024-05-26: $162.14
# Predicted closing price for 2024-05-27: $162.26
# Predicted closing price for 2024-05-28: $162.38
# Predicted closing price for 2024-05-29: $162.50
# Predicted closing price for 2024-05-30: $162.61
# Predicted closing price for 2024-05-31: $162.72
# Predicted closing price for 2024-06-01: $162.83
# Predicted closing price for 2024-06-02: $162.93
# Predicted closing price for 2024-06-03: $163.03
# Predicted closing price for 2024-06-04: $163.12
# Predicted closing price for 2024-06-05: $163.21
# Predicted closing price for 2024-06-06: $163.29
# Predicted closing price for 2024-06-07: $163.37
# Predicted closing price for 2024-06-08: $163.44
# Predicted closing price for 2024-06-09: $163.51
# Predicted closing price for 2024-06-10: $163.57
# Predicted closing price for 2024-06-11: $163.63
# Predicted closing price for 2024-06-12: $163.68
# Predicted closing price for 2024-06-13: $163.74
# Predicted closing price for 2024-06-14: $163.78
# Predicted closing price for 2024-06-15: $163.83
# Predicted closing price for 2024-06-16: $163.87
# Predicted closing price for 2024-06-17: $163.92
# Predicted closing price for 2024-06-18: $163.96
# Predicted closing price for 2024-06-19: $164.00
# Predicted closing price for 2024-06-20: $164.05
# Predicted closing price for 2024-06-21: $164.10
# Predicted closing price for 2024-06-22: $164.14
# Predicted closing price for 2024-06-23: $164.20
# Predicted closing price for 2024-06-24: $164.25
# Predicted closing price for 2024-06-25: $164.31
# Predicted closing price for 2024-06-26: $164.37
# Predicted closing price for 2024-06-27: $164.44
# Predicted closing price for 2024-06-28: $164.51
# Predicted closing price for 2024-06-29: $164.58
# Predicted closing price for 2024-06-30: $164.66
# Predicted closing price for 2024-07-01: $164.74
# Predicted closing price for 2024-07-02: $164.82
# Predicted closing price for 2024-07-03: $164.91
# Predicted closing price for 2024-07-04: $164.99
# Predicted closing price for 2024-07-05: $165.08
# Predicted closing price for 2024-07-06: $165.17
# Predicted closing price for 2024-07-07: $165.27
# Predicted closing price for 2024-07-08: $165.36
# Predicted closing price for 2024-07-09: $165.46
# Predicted closing price for 2024-07-10: $165.56
# Predicted closing price for 2024-07-11: $165.66
# Predicted closing price for 2024-07-12: $165.76
# Predicted closing price for 2024-07-13: $165.85
# Predicted closing price for 2024-07-14: $165.95
# Predicted closing price for 2024-07-15: $166.05
# Predicted closing price for 2024-07-16: $166.15
# Predicted closing price for 2024-07-17: $166.25
# Predicted closing price for 2024-07-18: $166.35
# Predicted closing price for 2024-07-19: $166.44
# Predicted closing price for 2024-07-20: $166.54
# Predicted closing price for 2024-07-21: $166.63
# Predicted closing price for 2024-07-22: $166.72
# Predicted closing price for 2024-07-23: $166.81
# Predicted closing price for 2024-07-24: $166.90
# Predicted closing price for 2024-07-25: $166.99
# Predicted closing price for 2024-07-26: $167.07
# Predicted closing price for 2024-07-27: $167.15
# Predicted closing price for 2024-07-28: $167.23
# Predicted closing price for 2024-07-29: $167.31
# Predicted closing price for 2024-07-30: $167.38
# Predicted closing price for 2024-07-31: $167.46
# Predicted closing price for 2024-08-01: $167.53
# Predicted closing price for 2024-08-02: $167.59
# Predicted closing price for 2024-08-03: $167.66
# Predicted closing price for 2024-08-04: $167.72
# Predicted closing price for 2024-08-05: $167.78
# Predicted closing price for 2024-08-06: $167.84
# Predicted closing price for 2024-08-07: $167.89
# Predicted closing price for 2024-08-08: $167.95
# Predicted closing price for 2024-08-09: $168.00
# Predicted closing price for 2024-08-10: $168.05
# Predicted closing price for 2024-08-11: $168.10
# Predicted closing price for 2024-08-12: $168.15
# Predicted closing price for 2024-08-13: $168.19
# Predicted closing price for 2024-08-14: $168.24
# Predicted closing price for 2024-08-15: $168.29
# Predicted closing price for 2024-08-16: $168.33
# Predicted closing price for 2024-08-17: $168.38
# Predicted closing price for 2024-08-18: $168.43
# Predicted closing price for 2024-08-19: $168.48
# Predicted closing price for 2024-08-20: $168.52
# Predicted closing price for 2024-08-21: $168.57
# Predicted closing price for 2024-08-22: $168.62
# Predicted closing price for 2024-08-23: $168.68
# Predicted closing price for 2024-08-24: $168.73
# Predicted closing price for 2024-08-25: $168.79
# Predicted closing price for 2024-08-26: $168.84
# Predicted closing price for 2024-08-27: $168.90
# Predicted closing price for 2024-08-28: $168.96
# Predicted closing price for 2024-08-29: $169.02
# Predicted closing price for 2024-08-30: $169.08
# Predicted closing price for 2024-08-31: $169.14
# Predicted closing price for 2024-09-01: $169.20
# Predicted closing price for 2024-09-02: $169.27
# Predicted closing price for 2024-09-03: $169.33
# Predicted closing price for 2024-09-04: $169.40
# Predicted closing price for 2024-09-05: $169.46
# Predicted closing price for 2024-09-06: $169.53
# Predicted closing price for 2024-09-07: $169.60
# Predicted closing price for 2024-09-08: $169.66
# Predicted closing price for 2024-09-09: $169.73
# Predicted closing price for 2024-09-10: $169.80
# Predicted closing price for 2024-09-11: $169.86
# Predicted closing price for 2024-09-12: $169.93
# Predicted closing price for 2024-09-13: $170.00
# Predicted closing price for 2024-09-14: $170.06
# Predicted closing price for 2024-09-15: $170.13
# Predicted closing price for 2024-09-16: $170.19
# Predicted closing price for 2024-09-17: $170.26
# Predicted closing price for 2024-09-18: $170.32
# Predicted closing price for 2024-09-19: $170.38
# Predicted closing price for 2024-09-20: $170.44
# Predicted closing price for 2024-09-21: $170.50
# Predicted closing price for 2024-09-22: $170.56
# Predicted closing price for 2024-09-23: $170.62
# Predicted closing price for 2024-09-24: $170.68
# Predicted closing price for 2024-09-25: $170.73
# Predicted closing price for 2024-09-26: $170.79
# Predicted closing price for 2024-09-27: $170.84
# Predicted closing price for 2024-09-28: $170.89
# Predicted closing price for 2024-09-29: $170.94
# Predicted closing price for 2024-09-30: $170.99
# Predicted closing price for 2024-10-01: $171.04
# Predicted closing price for 2024-10-02: $171.09
# Predicted closing price for 2024-10-03: $171.13
# Predicted closing price for 2024-10-04: $171.18
# Predicted closing price for 2024-10-05: $171.22
# Predicted closing price for 2024-10-06: $171.27
# Predicted closing price for 2024-10-07: $171.31
# Predicted closing price for 2024-10-08: $171.35
# Predicted closing price for 2024-10-09: $171.39
# Predicted closing price for 2024-10-10: $171.43
# Predicted closing price for 2024-10-11: $171.47
# Predicted closing price for 2024-10-12: $171.51
# Predicted closing price for 2024-10-13: $171.55
# Predicted closing price for 2024-10-14: $171.59
# Predicted closing price for 2024-10-15: $171.63
# Predicted closing price for 2024-10-16: $171.67
# Predicted closing price for 2024-10-17: $171.71
# Predicted closing price for 2024-10-18: $171.75
# Predicted closing price for 2024-10-19: $171.79
# Predicted closing price for 2024-10-20: $171.83
# Predicted closing price for 2024-10-21: $171.87
# Predicted closing price for 2024-10-22: $171.91
# Predicted closing price for 2024-10-23: $171.95
# Predicted closing price for 2024-10-24: $172.00
# Predicted closing price for 2024-10-25: $172.04
# Predicted closing price for 2024-10-26: $172.08
# Predicted closing price for 2024-10-27: $172.13
# Predicted closing price for 2024-10-28: $172.17
# Predicted closing price for 2024-10-29: $172.22
# Predicted closing price for 2024-10-30: $172.26
# Predicted closing price for 2024-10-31: $172.30
# Predicted closing price for 2024-11-01: $172.35
# Predicted closing price for 2024-11-02: $172.40
# Predicted closing price for 2024-11-03: $172.44
# Predicted closing price for 2024-11-04: $172.49
# Predicted closing price for 2024-11-05: $172.53
# Predicted closing price for 2024-11-06: $172.58
# Predicted closing price for 2024-11-07: $172.62
# Predicted closing price for 2024-11-08: $172.67
# Predicted closing price for 2024-11-09: $172.72
# Predicted closing price for 2024-11-10: $172.76
# Predicted closing price for 2024-11-11: $172.81
# Predicted closing price for 2024-11-12: $172.85
# Predicted closing price for 2024-11-13: $172.90
# Predicted closing price for 2024-11-14: $172.94
# Predicted closing price for 2024-11-15: $172.98
# Predicted closing price for 2024-11-16: $173.03
# Predicted closing price for 2024-11-17: $173.07
# Predicted closing price for 2024-11-18: $173.11
# Predicted closing price for 2024-11-19: $173.15
# Predicted closing price for 2024-11-20: $173.19
# Predicted closing price for 2024-11-21: $173.23
# Predicted closing price for 2024-11-22: $173.27
# Predicted closing price for 2024-11-23: $173.31

# %% [markdown]
# ### Visualize the Test Data and 365-Day Forecast

# %%
# Prepare the dates for forecasting by extending the existing dates array
forecast_dates = [df['Date'].iloc[-1] + pd.Timedelta(days=x + 1) for x in range(1, 366)]

plt.figure(figsize=(16, 8))
plt.title('Test Dataset and 365-Day Forecast')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

plt.plot(df['Date'][training_data_len:], y_test, label='Actual Values (Test)', color='Blue', alpha=0.3)
plt.plot(df['Date'][training_data_len:], test_predictions, label='Predicted Values (Test)', color='Green', alpha=0.9)
plt.plot(forecast_dates, predicted_prices, label='Forecasted Values', color='Red', alpha=0.9)

plt.xticks(rotation=45)
plt.legend(loc='lower right')
plt.tight_layout()
plt.show()
