# %% [markdown]
# ### Importing Libraries

# %%
import yfinance as yf
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from tensorflow.random import set_seed
import warnings
warnings.filterwarnings('ignore')
# Out:
# WARNING:tensorflow:From C:\Users\achan\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ### Data Collection

# %%
# Set random seeds for reproducibility
np.random.seed(42)
set_seed(42)

# Download stock data
ticker_symbol = 'GOOGL'
ticker_data = yf.Ticker(ticker_symbol)
df = ticker_data.history(period='1d', start='2015-11-01', end='2023-11-25')
df.reset_index(inplace=True)
df = df[['Date', 'Close']]
df
# Out:
#                           Date       Close
# 0    2015-11-02 00:00:00-05:00   37.387001
# 1    2015-11-03 00:00:00-05:00   37.441002
# 2    2015-11-04 00:00:00-05:00   37.765499
# 3    2015-11-05 00:00:00-05:00   38.033501
# 4    2015-11-06 00:00:00-05:00   38.080002
# ...                        ...         ...
# 2025 2023-11-17 00:00:00-05:00  135.309998
# 2026 2023-11-20 00:00:00-05:00  136.250000
# 2027 2023-11-21 00:00:00-05:00  136.970001
# 2028 2023-11-22 00:00:00-05:00  138.490005
# 2029 2023-11-24 00:00:00-05:00  136.690002
#
# [2030 rows x 2 columns]

# %% [markdown]
# ### Data Preprocessing

# %%
# Data is scaled to values between 0 and 1
scaler = MinMaxScaler(feature_range=(0, 1))
training_data_len = int(np.ceil(len(df) * 0.8))
scaler.fit(df['Close'].values[:training_data_len].reshape(-1, 1))
scaled_data = scaler.transform(df['Close'].values.reshape(-1, 1))

# %%
# Create the training and testing data set
train_data = scaled_data[0:training_data_len, :]
test_data = scaled_data[training_data_len - 60:, :]

# %%
# Split the data into x_train, y_train, x_test, and y_test data sets
x_train, y_train = [], []
x_test, y_test = [], df['Close'][training_data_len:].values
for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])

for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i, 0])

# %%
# Convert to numpy arrays for the LSTM model
x_train, y_train = np.array(x_train), np.array(y_train)
x_test, y_test = np.array(x_test), np.array(y_test)

# %%
# Reshape the data into the shape accepted by the LSTM
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %% [markdown]
# ### Build the LSTM Model

# %%
# Build the LSTM model with dropout layers to prevent overfitting
model = Sequential([
    LSTM(units=150, return_sequences=True, input_shape=(x_train.shape[1], 1)),
    Dropout(0.2),
    LSTM(units=150, return_sequences=False),
    Dropout(0.2),
    Dense(units=25),
    Dense(units=1)
])

# Compile the model with a mean squared error loss function and the adam optimizer
model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# WARNING:tensorflow:From C:\Users\achan\anaconda3\Lib\site-packages\keras\src\layers\rnn\lstm.py:148: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\achan\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# Train the model with early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
history = model.fit(x_train, y_train, batch_size=32, epochs=100, 
                    validation_data=(x_test, y_test), callbacks=[early_stopping], verbose=1)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\achan\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 49/49 [==============================] - 5s 63ms/step - loss: 0.0102 - val_loss: 12678.1875
# Epoch 2/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0013 - val_loss: 12680.8340
# Epoch 3/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0013 - val_loss: 12689.6895
# Epoch 4/100
# 49/49 [==============================] - 2s 42ms/step - loss: 0.0011 - val_loss: 12685.4844
# Epoch 5/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0013 - val_loss: 12688.1025
# Epoch 6/100
# 49/49 [==============================] - 3s 51ms/step - loss: 0.0011 - val_loss: 12679.4053
# Epoch 7/100
# 49/49 [==============================] - 2s 48ms/step - loss: 9.0843e-04 - val_loss: 12688.7891
# Epoch 8/100
# 49/49 [==============================] - 2s 42ms/step - loss: 8.8021e-04 - val_loss: 12680.4102
# Epoch 9/100
# 49/49 [==============================] - 2s 44ms/step - loss: 7.9355e-04 - val_loss: 12689.2773
# Epoch 10/100
# 49/49 [==============================] - 3s 51ms/step - loss: 9.4053e-04 - val_loss: 12678.5488
# Epoch 11/100
# 49/49 [==============================] - 2s 49ms/step - loss: 9.3410e-04 - val_loss: 12684.4043

# %% [markdown]
# ### Evaluate the Model and Print RMSE

# %%
# Predict on training set and test set
train_predictions = model.predict(x_train)
train_predictions = scaler.inverse_transform(train_predictions)
test_predictions = model.predict(x_test)
test_predictions = scaler.inverse_transform(test_predictions)
# Out:
# 49/49 [==============================] - 1s 13ms/step
# 13/13 [==============================] - 0s 13ms/step

# %%
# Calculate RMSE performance metrics
train_rmse = np.sqrt(mean_squared_error(y_train, train_predictions))
test_rmse = np.sqrt(mean_squared_error(y_test, test_predictions))
print(f"Train RMSE: {train_rmse}, Test RMSE: {test_rmse}")
# Out:
# Train RMSE: 78.25386585861438, Test RMSE: 5.7295085890650945

# %% [markdown]
# ### Visualize the Training Data and Predictions

# %%
# Visualize the training data and predictions
df['Date'] = pd.to_datetime(df['Date'])
adjusted_train_dates = df['Date'][60:training_data_len]

plt.figure(figsize=(16, 8))
plt.title('Train Dataset')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

plt.plot(df['Date'][:training_data_len], df['Close'][:training_data_len], label='Actual Values (Train)', color='blue')
plt.plot(adjusted_train_dates, train_predictions, label='Predicted Values (Train)', color='green')

plt.xticks(rotation=45)
plt.legend(loc='lower right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Forecasting the Next 365 Days

# %%
# Forecast the next 365 days
last_60_days = scaled_data[-60:]
predicted_prices = []

for i in range(365):
    X_pred_scaled = last_60_days.reshape(1, -1, 1)
    pred_price_scaled = model.predict(X_pred_scaled)
    predicted_prices.append(pred_price_scaled[0, 0])
    last_60_days = np.append(last_60_days, pred_price_scaled)[1:].reshape(-1, 1)

predicted_prices = scaler.inverse_transform(np.array(predicted_prices).reshape(-1, 1))

last_date = pd.to_datetime(df['Date'].iloc[-1])
prediction_dates = [last_date + pd.Timedelta(days=x + 1) for x in range(365)]
predicted_prices = predicted_prices.flatten()

for i in range(len(prediction_dates)):
    print(f"Predicted closing price for {prediction_dates[i].date()}: ${predicted_prices[i]:.2f}")
# Out:
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# Predicted closing price for 2023-11-25: $137.19
# Predicted closing price for 2023-11-26: $137.73
# Predicted closing price for 2023-11-27: $138.22
# Predicted closing price for 2023-11-28: $138.68
# Predicted closing price for 2023-11-29: $139.11
# Predicted closing price for 2023-11-30: $139.53
# Predicted closing price for 2023-12-01: $139.93
# Predicted closing price for 2023-12-02: $140.33
# Predicted closing price for 2023-12-03: $140.72
# Predicted closing price for 2023-12-04: $141.11
# Predicted closing price for 2023-12-05: $141.50
# Predicted closing price for 2023-12-06: $141.88
# Predicted closing price for 2023-12-07: $142.27
# Predicted closing price for 2023-12-08: $142.65
# Predicted closing price for 2023-12-09: $143.02
# Predicted closing price for 2023-12-10: $143.40
# Predicted closing price for 2023-12-11: $143.77
# Predicted closing price for 2023-12-12: $144.15
# Predicted closing price for 2023-12-13: $144.52
# Predicted closing price for 2023-12-14: $144.88
# Predicted closing price for 2023-12-15: $145.25
# Predicted closing price for 2023-12-16: $145.61
# Predicted closing price for 2023-12-17: $145.97
# Predicted closing price for 2023-12-18: $146.33
# Predicted closing price for 2023-12-19: $146.69
# Predicted closing price for 2023-12-20: $147.04
# Predicted closing price for 2023-12-21: $147.40
# Predicted closing price for 2023-12-22: $147.75
# Predicted closing price for 2023-12-23: $148.10
# Predicted closing price for 2023-12-24: $148.44
# Predicted closing price for 2023-12-25: $148.78
# Predicted closing price for 2023-12-26: $149.13
# Predicted closing price for 2023-12-27: $149.46
# Predicted closing price for 2023-12-28: $149.80
# Predicted closing price for 2023-12-29: $150.13
# Predicted closing price for 2023-12-30: $150.47
# Predicted closing price for 2023-12-31: $150.80
# Predicted closing price for 2024-01-01: $151.12
# Predicted closing price for 2024-01-02: $151.45
# Predicted closing price for 2024-01-03: $151.77
# Predicted closing price for 2024-01-04: $152.09
# Predicted closing price for 2024-01-05: $152.41
# Predicted closing price for 2024-01-06: $152.72
# Predicted closing price for 2024-01-07: $153.04
# Predicted closing price for 2024-01-08: $153.35
# Predicted closing price for 2024-01-09: $153.65
# Predicted closing price for 2024-01-10: $153.96
# Predicted closing price for 2024-01-11: $154.26
# Predicted closing price for 2024-01-12: $154.56
# Predicted closing price for 2024-01-13: $154.86
# Predicted closing price for 2024-01-14: $155.16
# Predicted closing price for 2024-01-15: $155.45
# Predicted closing price for 2024-01-16: $155.74
# Predicted closing price for 2024-01-17: $156.03
# Predicted closing price for 2024-01-18: $156.32
# Predicted closing price for 2024-01-19: $156.60
# Predicted closing price for 2024-01-20: $156.88
# Predicted closing price for 2024-01-21: $157.16
# Predicted closing price for 2024-01-22: $157.44
# Predicted closing price for 2024-01-23: $157.71
# Predicted closing price for 2024-01-24: $157.98
# Predicted closing price for 2024-01-25: $158.25
# Predicted closing price for 2024-01-26: $158.52
# Predicted closing price for 2024-01-27: $158.78
# Predicted closing price for 2024-01-28: $159.05
# Predicted closing price for 2024-01-29: $159.31
# Predicted closing price for 2024-01-30: $159.56
# Predicted closing price for 2024-01-31: $159.82
# Predicted closing price for 2024-02-01: $160.07
# Predicted closing price for 2024-02-02: $160.32
# Predicted closing price for 2024-02-03: $160.57
# Predicted closing price for 2024-02-04: $160.82
# Predicted closing price for 2024-02-05: $161.06
# Predicted closing price for 2024-02-06: $161.30
# Predicted closing price for 2024-02-07: $161.54
# Predicted closing price for 2024-02-08: $161.77
# Predicted closing price for 2024-02-09: $162.01
# Predicted closing price for 2024-02-10: $162.24
# Predicted closing price for 2024-02-11: $162.47
# Predicted closing price for 2024-02-12: $162.70
# Predicted closing price for 2024-02-13: $162.92
# Predicted closing price for 2024-02-14: $163.14
# Predicted closing price for 2024-02-15: $163.36
# Predicted closing price for 2024-02-16: $163.58
# Predicted closing price for 2024-02-17: $163.80
# Predicted closing price for 2024-02-18: $164.01
# Predicted closing price for 2024-02-19: $164.22
# Predicted closing price for 2024-02-20: $164.43
# Predicted closing price for 2024-02-21: $164.64
# Predicted closing price for 2024-02-22: $164.84
# Predicted closing price for 2024-02-23: $165.04
# Predicted closing price for 2024-02-24: $165.24
# Predicted closing price for 2024-02-25: $165.44
# Predicted closing price for 2024-02-26: $165.64
# Predicted closing price for 2024-02-27: $165.83
# Predicted closing price for 2024-02-28: $166.02
# Predicted closing price for 2024-02-29: $166.21
# Predicted closing price for 2024-03-01: $166.40
# Predicted closing price for 2024-03-02: $166.58
# Predicted closing price for 2024-03-03: $166.77
# Predicted closing price for 2024-03-04: $166.95
# Predicted closing price for 2024-03-05: $167.13
# Predicted closing price for 2024-03-06: $167.31
# Predicted closing price for 2024-03-07: $167.48
# Predicted closing price for 2024-03-08: $167.65
# Predicted closing price for 2024-03-09: $167.83
# Predicted closing price for 2024-03-10: $168.00
# Predicted closing price for 2024-03-11: $168.16
# Predicted closing price for 2024-03-12: $168.33
# Predicted closing price for 2024-03-13: $168.49
# Predicted closing price for 2024-03-14: $168.65
# Predicted closing price for 2024-03-15: $168.81
# Predicted closing price for 2024-03-16: $168.97
# Predicted closing price for 2024-03-17: $169.13
# Predicted closing price for 2024-03-18: $169.28
# Predicted closing price for 2024-03-19: $169.43
# Predicted closing price for 2024-03-20: $169.58
# Predicted closing price for 2024-03-21: $169.73
# Predicted closing price for 2024-03-22: $169.88
# Predicted closing price for 2024-03-23: $170.03
# Predicted closing price for 2024-03-24: $170.17
# Predicted closing price for 2024-03-25: $170.31
# Predicted closing price for 2024-03-26: $170.45
# Predicted closing price for 2024-03-27: $170.59
# Predicted closing price for 2024-03-28: $170.73
# Predicted closing price for 2024-03-29: $170.86
# Predicted closing price for 2024-03-30: $171.00
# Predicted closing price for 2024-03-31: $171.13
# Predicted closing price for 2024-04-01: $171.26
# Predicted closing price for 2024-04-02: $171.39
# Predicted closing price for 2024-04-03: $171.51
# Predicted closing price for 2024-04-04: $171.64
# Predicted closing price for 2024-04-05: $171.76
# Predicted closing price for 2024-04-06: $171.88
# Predicted closing price for 2024-04-07: $172.01
# Predicted closing price for 2024-04-08: $172.12
# Predicted closing price for 2024-04-09: $172.24
# Predicted closing price for 2024-04-10: $172.36
# Predicted closing price for 2024-04-11: $172.47
# Predicted closing price for 2024-04-12: $172.59
# Predicted closing price for 2024-04-13: $172.70
# Predicted closing price for 2024-04-14: $172.81
# Predicted closing price for 2024-04-15: $172.92
# Predicted closing price for 2024-04-16: $173.03
# Predicted closing price for 2024-04-17: $173.13
# Predicted closing price for 2024-04-18: $173.24
# Predicted closing price for 2024-04-19: $173.34
# Predicted closing price for 2024-04-20: $173.44
# Predicted closing price for 2024-04-21: $173.54
# Predicted closing price for 2024-04-22: $173.64
# Predicted closing price for 2024-04-23: $173.74
# Predicted closing price for 2024-04-24: $173.84
# Predicted closing price for 2024-04-25: $173.93
# Predicted closing price for 2024-04-26: $174.03
# Predicted closing price for 2024-04-27: $174.12
# Predicted closing price for 2024-04-28: $174.21
# Predicted closing price for 2024-04-29: $174.30
# Predicted closing price for 2024-04-30: $174.39
# Predicted closing price for 2024-05-01: $174.48
# Predicted closing price for 2024-05-02: $174.57
# Predicted closing price for 2024-05-03: $174.66
# Predicted closing price for 2024-05-04: $174.74
# Predicted closing price for 2024-05-05: $174.82
# Predicted closing price for 2024-05-06: $174.91
# Predicted closing price for 2024-05-07: $174.99
# Predicted closing price for 2024-05-08: $175.07
# Predicted closing price for 2024-05-09: $175.15
# Predicted closing price for 2024-05-10: $175.23
# Predicted closing price for 2024-05-11: $175.30
# Predicted closing price for 2024-05-12: $175.38
# Predicted closing price for 2024-05-13: $175.46
# Predicted closing price for 2024-05-14: $175.53
# Predicted closing price for 2024-05-15: $175.60
# Predicted closing price for 2024-05-16: $175.68
# Predicted closing price for 2024-05-17: $175.75
# Predicted closing price for 2024-05-18: $175.82
# Predicted closing price for 2024-05-19: $175.89
# Predicted closing price for 2024-05-20: $175.95
# Predicted closing price for 2024-05-21: $176.02
# Predicted closing price for 2024-05-22: $176.09
# Predicted closing price for 2024-05-23: $176.15
# Predicted closing price for 2024-05-24: $176.22
# Predicted closing price for 2024-05-25: $176.28
# Predicted closing price for 2024-05-26: $176.35
# Predicted closing price for 2024-05-27: $176.41
# Predicted closing price for 2024-05-28: $176.47
# Predicted closing price for 2024-05-29: $176.53
# Predicted closing price for 2024-05-30: $176.59
# Predicted closing price for 2024-05-31: $176.65
# Predicted closing price for 2024-06-01: $176.71
# Predicted closing price for 2024-06-02: $176.76
# Predicted closing price for 2024-06-03: $176.82
# Predicted closing price for 2024-06-04: $176.87
# Predicted closing price for 2024-06-05: $176.93
# Predicted closing price for 2024-06-06: $176.98
# Predicted closing price for 2024-06-07: $177.04
# Predicted closing price for 2024-06-08: $177.09
# Predicted closing price for 2024-06-09: $177.14
# Predicted closing price for 2024-06-10: $177.19
# Predicted closing price for 2024-06-11: $177.24
# Predicted closing price for 2024-06-12: $177.29
# Predicted closing price for 2024-06-13: $177.34
# Predicted closing price for 2024-06-14: $177.39
# Predicted closing price for 2024-06-15: $177.44
# Predicted closing price for 2024-06-16: $177.48
# Predicted closing price for 2024-06-17: $177.53
# Predicted closing price for 2024-06-18: $177.57
# Predicted closing price for 2024-06-19: $177.62
# Predicted closing price for 2024-06-20: $177.66
# Predicted closing price for 2024-06-21: $177.71
# Predicted closing price for 2024-06-22: $177.75
# Predicted closing price for 2024-06-23: $177.79
# Predicted closing price for 2024-06-24: $177.83
# Predicted closing price for 2024-06-25: $177.88
# Predicted closing price for 2024-06-26: $177.92
# Predicted closing price for 2024-06-27: $177.96
# Predicted closing price for 2024-06-28: $178.00
# Predicted closing price for 2024-06-29: $178.03
# Predicted closing price for 2024-06-30: $178.07
# Predicted closing price for 2024-07-01: $178.11
# Predicted closing price for 2024-07-02: $178.15
# Predicted closing price for 2024-07-03: $178.18
# Predicted closing price for 2024-07-04: $178.22
# Predicted closing price for 2024-07-05: $178.26
# Predicted closing price for 2024-07-06: $178.29
# Predicted closing price for 2024-07-07: $178.33
# Predicted closing price for 2024-07-08: $178.36
# Predicted closing price for 2024-07-09: $178.39
# Predicted closing price for 2024-07-10: $178.43
# Predicted closing price for 2024-07-11: $178.46
# Predicted closing price for 2024-07-12: $178.49
# Predicted closing price for 2024-07-13: $178.52
# Predicted closing price for 2024-07-14: $178.56
# Predicted closing price for 2024-07-15: $178.59
# Predicted closing price for 2024-07-16: $178.62
# Predicted closing price for 2024-07-17: $178.65
# Predicted closing price for 2024-07-18: $178.68
# Predicted closing price for 2024-07-19: $178.71
# Predicted closing price for 2024-07-20: $178.73
# Predicted closing price for 2024-07-21: $178.76
# Predicted closing price for 2024-07-22: $178.79
# Predicted closing price for 2024-07-23: $178.82
# Predicted closing price for 2024-07-24: $178.85
# Predicted closing price for 2024-07-25: $178.87
# Predicted closing price for 2024-07-26: $178.90
# Predicted closing price for 2024-07-27: $178.92
# Predicted closing price for 2024-07-28: $178.95
# Predicted closing price for 2024-07-29: $178.97
# Predicted closing price for 2024-07-30: $179.00
# Predicted closing price for 2024-07-31: $179.02
# Predicted closing price for 2024-08-01: $179.05
# Predicted closing price for 2024-08-02: $179.07
# Predicted closing price for 2024-08-03: $179.10
# Predicted closing price for 2024-08-04: $179.12
# Predicted closing price for 2024-08-05: $179.14
# Predicted closing price for 2024-08-06: $179.16
# Predicted closing price for 2024-08-07: $179.19
# Predicted closing price for 2024-08-08: $179.21
# Predicted closing price for 2024-08-09: $179.23
# Predicted closing price for 2024-08-10: $179.25
# Predicted closing price for 2024-08-11: $179.27
# Predicted closing price for 2024-08-12: $179.29
# Predicted closing price for 2024-08-13: $179.31
# Predicted closing price for 2024-08-14: $179.33
# Predicted closing price for 2024-08-15: $179.35
# Predicted closing price for 2024-08-16: $179.37
# Predicted closing price for 2024-08-17: $179.39
# Predicted closing price for 2024-08-18: $179.41
# Predicted closing price for 2024-08-19: $179.43
# Predicted closing price for 2024-08-20: $179.44
# Predicted closing price for 2024-08-21: $179.46
# Predicted closing price for 2024-08-22: $179.48
# Predicted closing price for 2024-08-23: $179.50
# Predicted closing price for 2024-08-24: $179.52
# Predicted closing price for 2024-08-25: $179.53
# Predicted closing price for 2024-08-26: $179.55
# Predicted closing price for 2024-08-27: $179.57
# Predicted closing price for 2024-08-28: $179.58
# Predicted closing price for 2024-08-29: $179.60
# Predicted closing price for 2024-08-30: $179.61
# Predicted closing price for 2024-08-31: $179.63
# Predicted closing price for 2024-09-01: $179.64
# Predicted closing price for 2024-09-02: $179.66
# Predicted closing price for 2024-09-03: $179.67
# Predicted closing price for 2024-09-04: $179.69
# Predicted closing price for 2024-09-05: $179.70
# Predicted closing price for 2024-09-06: $179.72
# Predicted closing price for 2024-09-07: $179.73
# Predicted closing price for 2024-09-08: $179.74
# Predicted closing price for 2024-09-09: $179.76
# Predicted closing price for 2024-09-10: $179.77
# Predicted closing price for 2024-09-11: $179.78
# Predicted closing price for 2024-09-12: $179.80
# Predicted closing price for 2024-09-13: $179.81
# Predicted closing price for 2024-09-14: $179.82
# Predicted closing price for 2024-09-15: $179.84
# Predicted closing price for 2024-09-16: $179.85
# Predicted closing price for 2024-09-17: $179.86
# Predicted closing price for 2024-09-18: $179.87
# Predicted closing price for 2024-09-19: $179.88
# Predicted closing price for 2024-09-20: $179.89
# Predicted closing price for 2024-09-21: $179.91
# Predicted closing price for 2024-09-22: $179.92
# Predicted closing price for 2024-09-23: $179.93
# Predicted closing price for 2024-09-24: $179.94
# Predicted closing price for 2024-09-25: $179.95
# Predicted closing price for 2024-09-26: $179.96
# Predicted closing price for 2024-09-27: $179.97
# Predicted closing price for 2024-09-28: $179.98
# Predicted closing price for 2024-09-29: $179.99
# Predicted closing price for 2024-09-30: $180.00
# Predicted closing price for 2024-10-01: $180.01
# Predicted closing price for 2024-10-02: $180.02
# Predicted closing price for 2024-10-03: $180.03
# Predicted closing price for 2024-10-04: $180.04
# Predicted closing price for 2024-10-05: $180.05
# Predicted closing price for 2024-10-06: $180.06
# Predicted closing price for 2024-10-07: $180.07
# Predicted closing price for 2024-10-08: $180.07
# Predicted closing price for 2024-10-09: $180.08
# Predicted closing price for 2024-10-10: $180.09
# Predicted closing price for 2024-10-11: $180.10
# Predicted closing price for 2024-10-12: $180.11
# Predicted closing price for 2024-10-13: $180.12
# Predicted closing price for 2024-10-14: $180.12
# Predicted closing price for 2024-10-15: $180.13
# Predicted closing price for 2024-10-16: $180.14
# Predicted closing price for 2024-10-17: $180.15
# Predicted closing price for 2024-10-18: $180.16
# Predicted closing price for 2024-10-19: $180.16
# Predicted closing price for 2024-10-20: $180.17
# Predicted closing price for 2024-10-21: $180.18
# Predicted closing price for 2024-10-22: $180.18
# Predicted closing price for 2024-10-23: $180.19
# Predicted closing price for 2024-10-24: $180.20
# Predicted closing price for 2024-10-25: $180.21
# Predicted closing price for 2024-10-26: $180.21
# Predicted closing price for 2024-10-27: $180.22
# Predicted closing price for 2024-10-28: $180.23
# Predicted closing price for 2024-10-29: $180.23
# Predicted closing price for 2024-10-30: $180.24
# Predicted closing price for 2024-10-31: $180.24
# Predicted closing price for 2024-11-01: $180.25
# Predicted closing price for 2024-11-02: $180.26
# Predicted closing price for 2024-11-03: $180.26
# Predicted closing price for 2024-11-04: $180.27
# Predicted closing price for 2024-11-05: $180.27
# Predicted closing price for 2024-11-06: $180.28
# Predicted closing price for 2024-11-07: $180.29
# Predicted closing price for 2024-11-08: $180.29
# Predicted closing price for 2024-11-09: $180.30
# Predicted closing price for 2024-11-10: $180.30
# Predicted closing price for 2024-11-11: $180.31
# Predicted closing price for 2024-11-12: $180.31
# Predicted closing price for 2024-11-13: $180.32
# Predicted closing price for 2024-11-14: $180.32
# Predicted closing price for 2024-11-15: $180.33
# Predicted closing price for 2024-11-16: $180.33
# Predicted closing price for 2024-11-17: $180.34
# Predicted closing price for 2024-11-18: $180.34
# Predicted closing price for 2024-11-19: $180.35
# Predicted closing price for 2024-11-20: $180.35
# Predicted closing price for 2024-11-21: $180.36
# Predicted closing price for 2024-11-22: $180.36
# Predicted closing price for 2024-11-23: $180.36

# %% [markdown]
# ### Visualize the Test Data and 365-Day Forecast

# %%
# Prepare the dates for forecasting by extending the existing dates array
forecast_dates = [df['Date'].iloc[-1] + pd.Timedelta(days=x + 1) for x in range(1, 366)]

plt.figure(figsize=(16, 8))
plt.title('Test Dataset and 365-Day Forecast')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

plt.plot(df['Date'][training_data_len:], y_test, label='Actual Values (Test)', color='Blue', alpha=0.3)
plt.plot(df['Date'][training_data_len:], test_predictions, label='Predicted Values (Test)', color='green', alpha=0.9)
plt.plot(forecast_dates, predicted_prices, label='Forecasted Values', color='red', alpha=0.9)

plt.xticks(rotation=45)
plt.legend(loc='lower right')
plt.tight_layout()
plt.show()
