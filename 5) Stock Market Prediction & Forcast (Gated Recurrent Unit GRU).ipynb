# %% [markdown]
# ### Import Required Libraries

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.dates as mdates
from tensorflow.random import set_seed
import warnings
warnings.filterwarnings('ignore')
# Out:
# WARNING:tensorflow:From C:\Users\achan\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ### Data Collection

# %%
# Set random seeds for reproducibility
np.random.seed(42)
set_seed(42)

# Download stock data
ticker_symbol = 'GOOGL'
ticker_data = yf.Ticker(ticker_symbol)
df = ticker_data.history(period='1d', start='2015-11-01', end='2023-11-09')
df.reset_index(inplace=True)
df = df[['Date', 'Close']]
df
# Out:
#                           Date       Close
# 0    2015-11-02 00:00:00-05:00   37.387001
# 1    2015-11-03 00:00:00-05:00   37.441002
# 2    2015-11-04 00:00:00-05:00   37.765499
# 3    2015-11-05 00:00:00-05:00   38.033501
# 4    2015-11-06 00:00:00-05:00   38.080002
# ...                        ...         ...
# 2014 2023-11-02 00:00:00-04:00  127.489998
# 2015 2023-11-03 00:00:00-04:00  129.100006
# 2016 2023-11-06 00:00:00-05:00  130.250000
# 2017 2023-11-07 00:00:00-05:00  130.970001
# 2018 2023-11-08 00:00:00-05:00  131.839996
#
# [2019 rows x 2 columns]

# %% [markdown]
# ### Data Preprocessing

# %%
# Data is scaled to values between 0 and 1
scaler = MinMaxScaler(feature_range=(0, 1))
training_data_len = int(np.ceil(len(df) * 0.8))
scaler.fit(df['Close'].values[:training_data_len].reshape(-1, 1))
scaled_data = scaler.transform(df['Close'].values.reshape(-1, 1))

# %%
# Create the training and testing data set
train_data = scaled_data[0:training_data_len, :]
test_data = scaled_data[training_data_len - 60:, :]

# %%
# Split the data into x_train, y_train, x_test, and y_test data sets
x_train, y_train = [], []
x_test, y_test = [], df['Close'][training_data_len:].values
for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])

for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i, 0])

# %%
# Convert to numpy arrays 
x_train, y_train = np.array(x_train), np.array(y_train)
x_test, y_test = np.array(x_test), np.array(y_test)

# %%
# Reshape the data into the shape accepted 
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %% [markdown]
# ### Build the GRU Model

# %%
# Build the GRU Model
model = Sequential([
    GRU(units=50, return_sequences=True, input_shape=(x_train.shape[1], 1)),
    Dropout(0.2),
    GRU(units=50, return_sequences=False),
    Dropout(0.2),
    Dense(units=25),
    Dense(units=1)
])

# Compile the model with a mean squared error loss function and the adam optimizer
model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# WARNING:tensorflow:From C:\Users\achan\anaconda3\Lib\site-packages\keras\src\layers\rnn\gru.py:144: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\achan\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# Train the model with early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
history = model.fit(x_train, y_train, batch_size=32, epochs=100, 
                    validation_data=(x_test, y_test), callbacks=[early_stopping], verbose=1)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\achan\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 49/49 [==============================] - 4s 31ms/step - loss: 0.0200 - val_loss: 12638.7646
# Epoch 2/100
# 49/49 [==============================] - 1s 18ms/step - loss: 0.0027 - val_loss: 12649.7578
# Epoch 3/100
# 49/49 [==============================] - 1s 17ms/step - loss: 0.0022 - val_loss: 12646.2441
# Epoch 4/100
# 49/49 [==============================] - 1s 17ms/step - loss: 0.0017 - val_loss: 12644.9443
# Epoch 5/100
# 49/49 [==============================] - 1s 18ms/step - loss: 0.0016 - val_loss: 12634.1182
# Epoch 6/100
# 49/49 [==============================] - 1s 17ms/step - loss: 0.0017 - val_loss: 12649.1006
# Epoch 7/100
# 49/49 [==============================] - 1s 17ms/step - loss: 0.0014 - val_loss: 12644.9600
# Epoch 8/100
# 49/49 [==============================] - 1s 18ms/step - loss: 0.0012 - val_loss: 12643.8594
# Epoch 9/100
# 49/49 [==============================] - 1s 20ms/step - loss: 0.0013 - val_loss: 12647.0146
# Epoch 10/100
# 49/49 [==============================] - 1s 19ms/step - loss: 0.0012 - val_loss: 12635.8662
# Epoch 11/100
# 49/49 [==============================] - 1s 20ms/step - loss: 0.0011 - val_loss: 12644.6797
# Epoch 12/100
# 49/49 [==============================] - 1s 20ms/step - loss: 0.0010 - val_loss: 12644.4365
# Epoch 13/100
# 49/49 [==============================] - 1s 19ms/step - loss: 0.0011 - val_loss: 12635.0566
# Epoch 14/100
# 49/49 [==============================] - 1s 20ms/step - loss: 9.5748e-04 - val_loss: 12644.0244
# Epoch 15/100
# 49/49 [==============================] - 1s 19ms/step - loss: 0.0010 - val_loss: 12642.7861

# %% [markdown]
# ### Evaluate the Model and Print RMSE

# %%
# Predict on training set and test set
train_predictions = model.predict(x_train)
train_predictions = scaler.inverse_transform(train_predictions)
test_predictions = model.predict(x_test)
test_predictions = scaler.inverse_transform(test_predictions)
# Out:
# 49/49 [==============================] - 1s 6ms/step
# 13/13 [==============================] - 0s 6ms/step

# %%
# Calculate RMSE performance metrics
train_rmse = np.sqrt(mean_squared_error(y_train, train_predictions))
test_rmse = np.sqrt(mean_squared_error(y_test, test_predictions))
print(f"Train RMSE: {train_rmse}, Test RMSE: {test_rmse}")
# Out:
# Train RMSE: 78.91699741147092, Test RMSE: 5.848279368098334

# %% [markdown]
# ### Visualize the Training Data and Predictions

# %%
# Visualize the training data and predictions
df['Date'] = pd.to_datetime(df['Date'])
adjusted_train_dates = df['Date'][60:training_data_len]

plt.figure(figsize=(16, 8))
plt.title('Train Dataset')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

plt.plot(df['Date'][:training_data_len], df['Close'][:training_data_len], label='Actual Values (Train)', color='blue')
plt.plot(adjusted_train_dates, train_predictions, label='Predicted Values (Train)', color='green')

plt.xticks(rotation=45)
plt.legend(loc='lower right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Forecasting the Next 365 Days

# %%
# Forecast the next 365 days
last_60_days = scaled_data[-60:]
predicted_prices = []

for i in range(365):
    X_pred_scaled = last_60_days.reshape(1, -1, 1)
    pred_price_scaled = model.predict(X_pred_scaled)
    predicted_prices.append(pred_price_scaled[0, 0])
    last_60_days = np.append(last_60_days, pred_price_scaled)[1:].reshape(-1, 1)

predicted_prices = scaler.inverse_transform(np.array(predicted_prices).reshape(-1, 1))

last_date = pd.to_datetime(df['Date'].iloc[-1])
prediction_dates = [last_date + pd.Timedelta(days=x + 1) for x in range(365)]
predicted_prices = predicted_prices.flatten()

for i in range(len(prediction_dates)):
    print(f"Predicted closing price for {prediction_dates[i].date()}: ${predicted_prices[i]:.2f}")
# Out:
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# Predicted closing price for 2023-11-09: $133.69
# Predicted closing price for 2023-11-10: $134.75
# Predicted closing price for 2023-11-11: $135.88
# Predicted closing price for 2023-11-12: $137.04
# Predicted closing price for 2023-11-13: $138.21
# Predicted closing price for 2023-11-14: $139.38
# Predicted closing price for 2023-11-15: $140.56
# Predicted closing price for 2023-11-16: $141.74
# Predicted closing price for 2023-11-17: $142.92
# Predicted closing price for 2023-11-18: $144.10
# Predicted closing price for 2023-11-19: $145.27
# Predicted closing price for 2023-11-20: $146.45
# Predicted closing price for 2023-11-21: $147.63
# Predicted closing price for 2023-11-22: $148.80
# Predicted closing price for 2023-11-23: $149.97
# Predicted closing price for 2023-11-24: $151.13
# Predicted closing price for 2023-11-25: $152.30
# Predicted closing price for 2023-11-26: $153.46
# Predicted closing price for 2023-11-27: $154.61
# Predicted closing price for 2023-11-28: $155.76
# Predicted closing price for 2023-11-29: $156.91
# Predicted closing price for 2023-11-30: $158.05
# Predicted closing price for 2023-12-01: $159.19
# Predicted closing price for 2023-12-02: $160.32
# Predicted closing price for 2023-12-03: $161.44
# Predicted closing price for 2023-12-04: $162.56
# Predicted closing price for 2023-12-05: $163.67
# Predicted closing price for 2023-12-06: $164.77
# Predicted closing price for 2023-12-07: $165.87
# Predicted closing price for 2023-12-08: $166.96
# Predicted closing price for 2023-12-09: $168.04
# Predicted closing price for 2023-12-10: $169.11
# Predicted closing price for 2023-12-11: $170.18
# Predicted closing price for 2023-12-12: $171.23
# Predicted closing price for 2023-12-13: $172.28
# Predicted closing price for 2023-12-14: $173.32
# Predicted closing price for 2023-12-15: $174.35
# Predicted closing price for 2023-12-16: $175.37
# Predicted closing price for 2023-12-17: $176.37
# Predicted closing price for 2023-12-18: $177.37
# Predicted closing price for 2023-12-19: $178.36
# Predicted closing price for 2023-12-20: $179.34
# Predicted closing price for 2023-12-21: $180.31
# Predicted closing price for 2023-12-22: $181.26
# Predicted closing price for 2023-12-23: $182.21
# Predicted closing price for 2023-12-24: $183.14
# Predicted closing price for 2023-12-25: $184.06
# Predicted closing price for 2023-12-26: $184.97
# Predicted closing price for 2023-12-27: $185.87
# Predicted closing price for 2023-12-28: $186.76
# Predicted closing price for 2023-12-29: $187.64
# Predicted closing price for 2023-12-30: $188.50
# Predicted closing price for 2023-12-31: $189.36
# Predicted closing price for 2024-01-01: $190.20
# Predicted closing price for 2024-01-02: $191.02
# Predicted closing price for 2024-01-03: $191.84
# Predicted closing price for 2024-01-04: $192.65
# Predicted closing price for 2024-01-05: $193.44
# Predicted closing price for 2024-01-06: $194.22
# Predicted closing price for 2024-01-07: $194.99
# Predicted closing price for 2024-01-08: $195.74
# Predicted closing price for 2024-01-09: $196.48
# Predicted closing price for 2024-01-10: $197.22
# Predicted closing price for 2024-01-11: $197.94
# Predicted closing price for 2024-01-12: $198.64
# Predicted closing price for 2024-01-13: $199.34
# Predicted closing price for 2024-01-14: $200.02
# Predicted closing price for 2024-01-15: $200.69
# Predicted closing price for 2024-01-16: $201.35
# Predicted closing price for 2024-01-17: $202.00
# Predicted closing price for 2024-01-18: $202.63
# Predicted closing price for 2024-01-19: $203.26
# Predicted closing price for 2024-01-20: $203.87
# Predicted closing price for 2024-01-21: $204.47
# Predicted closing price for 2024-01-22: $205.06
# Predicted closing price for 2024-01-23: $205.64
# Predicted closing price for 2024-01-24: $206.21
# Predicted closing price for 2024-01-25: $206.76
# Predicted closing price for 2024-01-26: $207.31
# Predicted closing price for 2024-01-27: $207.84
# Predicted closing price for 2024-01-28: $208.36
# Predicted closing price for 2024-01-29: $208.88
# Predicted closing price for 2024-01-30: $209.38
# Predicted closing price for 2024-01-31: $209.87
# Predicted closing price for 2024-02-01: $210.35
# Predicted closing price for 2024-02-02: $210.82
# Predicted closing price for 2024-02-03: $211.29
# Predicted closing price for 2024-02-04: $211.74
# Predicted closing price for 2024-02-05: $212.18
# Predicted closing price for 2024-02-06: $212.61
# Predicted closing price for 2024-02-07: $213.04
# Predicted closing price for 2024-02-08: $213.45
# Predicted closing price for 2024-02-09: $213.86
# Predicted closing price for 2024-02-10: $214.25
# Predicted closing price for 2024-02-11: $214.64
# Predicted closing price for 2024-02-12: $215.02
# Predicted closing price for 2024-02-13: $215.39
# Predicted closing price for 2024-02-14: $215.75
# Predicted closing price for 2024-02-15: $216.10
# Predicted closing price for 2024-02-16: $216.45
# Predicted closing price for 2024-02-17: $216.78
# Predicted closing price for 2024-02-18: $217.11
# Predicted closing price for 2024-02-19: $217.44
# Predicted closing price for 2024-02-20: $217.75
# Predicted closing price for 2024-02-21: $218.06
# Predicted closing price for 2024-02-22: $218.36
# Predicted closing price for 2024-02-23: $218.65
# Predicted closing price for 2024-02-24: $218.94
# Predicted closing price for 2024-02-25: $219.22
# Predicted closing price for 2024-02-26: $219.49
# Predicted closing price for 2024-02-27: $219.75
# Predicted closing price for 2024-02-28: $220.01
# Predicted closing price for 2024-02-29: $220.27
# Predicted closing price for 2024-03-01: $220.51
# Predicted closing price for 2024-03-02: $220.75
# Predicted closing price for 2024-03-03: $220.99
# Predicted closing price for 2024-03-04: $221.22
# Predicted closing price for 2024-03-05: $221.44
# Predicted closing price for 2024-03-06: $221.66
# Predicted closing price for 2024-03-07: $221.87
# Predicted closing price for 2024-03-08: $222.08
# Predicted closing price for 2024-03-09: $222.28
# Predicted closing price for 2024-03-10: $222.48
# Predicted closing price for 2024-03-11: $222.67
# Predicted closing price for 2024-03-12: $222.86
# Predicted closing price for 2024-03-13: $223.04
# Predicted closing price for 2024-03-14: $223.22
# Predicted closing price for 2024-03-15: $223.40
# Predicted closing price for 2024-03-16: $223.56
# Predicted closing price for 2024-03-17: $223.73
# Predicted closing price for 2024-03-18: $223.89
# Predicted closing price for 2024-03-19: $224.05
# Predicted closing price for 2024-03-20: $224.20
# Predicted closing price for 2024-03-21: $224.35
# Predicted closing price for 2024-03-22: $224.49
# Predicted closing price for 2024-03-23: $224.63
# Predicted closing price for 2024-03-24: $224.77
# Predicted closing price for 2024-03-25: $224.91
# Predicted closing price for 2024-03-26: $225.04
# Predicted closing price for 2024-03-27: $225.16
# Predicted closing price for 2024-03-28: $225.29
# Predicted closing price for 2024-03-29: $225.41
# Predicted closing price for 2024-03-30: $225.53
# Predicted closing price for 2024-03-31: $225.64
# Predicted closing price for 2024-04-01: $225.75
# Predicted closing price for 2024-04-02: $225.86
# Predicted closing price for 2024-04-03: $225.97
# Predicted closing price for 2024-04-04: $226.07
# Predicted closing price for 2024-04-05: $226.17
# Predicted closing price for 2024-04-06: $226.27
# Predicted closing price for 2024-04-07: $226.36
# Predicted closing price for 2024-04-08: $226.46
# Predicted closing price for 2024-04-09: $226.55
# Predicted closing price for 2024-04-10: $226.63
# Predicted closing price for 2024-04-11: $226.72
# Predicted closing price for 2024-04-12: $226.80
# Predicted closing price for 2024-04-13: $226.88
# Predicted closing price for 2024-04-14: $226.96
# Predicted closing price for 2024-04-15: $227.04
# Predicted closing price for 2024-04-16: $227.11
# Predicted closing price for 2024-04-17: $227.19
# Predicted closing price for 2024-04-18: $227.26
# Predicted closing price for 2024-04-19: $227.33
# Predicted closing price for 2024-04-20: $227.39
# Predicted closing price for 2024-04-21: $227.46
# Predicted closing price for 2024-04-22: $227.52
# Predicted closing price for 2024-04-23: $227.58
# Predicted closing price for 2024-04-24: $227.64
# Predicted closing price for 2024-04-25: $227.70
# Predicted closing price for 2024-04-26: $227.76
# Predicted closing price for 2024-04-27: $227.82
# Predicted closing price for 2024-04-28: $227.87
# Predicted closing price for 2024-04-29: $227.92
# Predicted closing price for 2024-04-30: $227.97
# Predicted closing price for 2024-05-01: $228.02
# Predicted closing price for 2024-05-02: $228.07
# Predicted closing price for 2024-05-03: $228.12
# Predicted closing price for 2024-05-04: $228.16
# Predicted closing price for 2024-05-05: $228.21
# Predicted closing price for 2024-05-06: $228.25
# Predicted closing price for 2024-05-07: $228.30
# Predicted closing price for 2024-05-08: $228.34
# Predicted closing price for 2024-05-09: $228.38
# Predicted closing price for 2024-05-10: $228.42
# Predicted closing price for 2024-05-11: $228.45
# Predicted closing price for 2024-05-12: $228.49
# Predicted closing price for 2024-05-13: $228.53
# Predicted closing price for 2024-05-14: $228.56
# Predicted closing price for 2024-05-15: $228.59
# Predicted closing price for 2024-05-16: $228.63
# Predicted closing price for 2024-05-17: $228.66
# Predicted closing price for 2024-05-18: $228.69
# Predicted closing price for 2024-05-19: $228.72
# Predicted closing price for 2024-05-20: $228.75
# Predicted closing price for 2024-05-21: $228.78
# Predicted closing price for 2024-05-22: $228.81
# Predicted closing price for 2024-05-23: $228.84
# Predicted closing price for 2024-05-24: $228.86
# Predicted closing price for 2024-05-25: $228.89
# Predicted closing price for 2024-05-26: $228.91
# Predicted closing price for 2024-05-27: $228.94
# Predicted closing price for 2024-05-28: $228.96
# Predicted closing price for 2024-05-29: $228.98
# Predicted closing price for 2024-05-30: $229.01
# Predicted closing price for 2024-05-31: $229.03
# Predicted closing price for 2024-06-01: $229.05
# Predicted closing price for 2024-06-02: $229.07
# Predicted closing price for 2024-06-03: $229.09
# Predicted closing price for 2024-06-04: $229.11
# Predicted closing price for 2024-06-05: $229.13
# Predicted closing price for 2024-06-06: $229.15
# Predicted closing price for 2024-06-07: $229.17
# Predicted closing price for 2024-06-08: $229.18
# Predicted closing price for 2024-06-09: $229.20
# Predicted closing price for 2024-06-10: $229.22
# Predicted closing price for 2024-06-11: $229.23
# Predicted closing price for 2024-06-12: $229.25
# Predicted closing price for 2024-06-13: $229.26
# Predicted closing price for 2024-06-14: $229.28
# Predicted closing price for 2024-06-15: $229.29
# Predicted closing price for 2024-06-16: $229.31
# Predicted closing price for 2024-06-17: $229.32
# Predicted closing price for 2024-06-18: $229.33
# Predicted closing price for 2024-06-19: $229.35
# Predicted closing price for 2024-06-20: $229.36
# Predicted closing price for 2024-06-21: $229.37
# Predicted closing price for 2024-06-22: $229.38
# Predicted closing price for 2024-06-23: $229.40
# Predicted closing price for 2024-06-24: $229.41
# Predicted closing price for 2024-06-25: $229.42
# Predicted closing price for 2024-06-26: $229.43
# Predicted closing price for 2024-06-27: $229.44
# Predicted closing price for 2024-06-28: $229.45
# Predicted closing price for 2024-06-29: $229.46
# Predicted closing price for 2024-06-30: $229.47
# Predicted closing price for 2024-07-01: $229.48
# Predicted closing price for 2024-07-02: $229.49
# Predicted closing price for 2024-07-03: $229.50
# Predicted closing price for 2024-07-04: $229.50
# Predicted closing price for 2024-07-05: $229.51
# Predicted closing price for 2024-07-06: $229.52
# Predicted closing price for 2024-07-07: $229.53
# Predicted closing price for 2024-07-08: $229.54
# Predicted closing price for 2024-07-09: $229.54
# Predicted closing price for 2024-07-10: $229.55
# Predicted closing price for 2024-07-11: $229.56
# Predicted closing price for 2024-07-12: $229.56
# Predicted closing price for 2024-07-13: $229.57
# Predicted closing price for 2024-07-14: $229.58
# Predicted closing price for 2024-07-15: $229.58
# Predicted closing price for 2024-07-16: $229.59
# Predicted closing price for 2024-07-17: $229.60
# Predicted closing price for 2024-07-18: $229.60
# Predicted closing price for 2024-07-19: $229.61
# Predicted closing price for 2024-07-20: $229.61
# Predicted closing price for 2024-07-21: $229.62
# Predicted closing price for 2024-07-22: $229.62
# Predicted closing price for 2024-07-23: $229.63
# Predicted closing price for 2024-07-24: $229.63
# Predicted closing price for 2024-07-25: $229.64
# Predicted closing price for 2024-07-26: $229.64
# Predicted closing price for 2024-07-27: $229.65
# Predicted closing price for 2024-07-28: $229.65
# Predicted closing price for 2024-07-29: $229.66
# Predicted closing price for 2024-07-30: $229.66
# Predicted closing price for 2024-07-31: $229.66
# Predicted closing price for 2024-08-01: $229.67
# Predicted closing price for 2024-08-02: $229.67
# Predicted closing price for 2024-08-03: $229.67
# Predicted closing price for 2024-08-04: $229.68
# Predicted closing price for 2024-08-05: $229.68
# Predicted closing price for 2024-08-06: $229.69
# Predicted closing price for 2024-08-07: $229.69
# Predicted closing price for 2024-08-08: $229.69
# Predicted closing price for 2024-08-09: $229.69
# Predicted closing price for 2024-08-10: $229.70
# Predicted closing price for 2024-08-11: $229.70
# Predicted closing price for 2024-08-12: $229.70
# Predicted closing price for 2024-08-13: $229.71
# Predicted closing price for 2024-08-14: $229.71
# Predicted closing price for 2024-08-15: $229.71
# Predicted closing price for 2024-08-16: $229.71
# Predicted closing price for 2024-08-17: $229.72
# Predicted closing price for 2024-08-18: $229.72
# Predicted closing price for 2024-08-19: $229.72
# Predicted closing price for 2024-08-20: $229.72
# Predicted closing price for 2024-08-21: $229.73
# Predicted closing price for 2024-08-22: $229.73
# Predicted closing price for 2024-08-23: $229.73
# Predicted closing price for 2024-08-24: $229.73
# Predicted closing price for 2024-08-25: $229.73
# Predicted closing price for 2024-08-26: $229.74
# Predicted closing price for 2024-08-27: $229.74
# Predicted closing price for 2024-08-28: $229.74
# Predicted closing price for 2024-08-29: $229.74
# Predicted closing price for 2024-08-30: $229.74
# Predicted closing price for 2024-08-31: $229.75
# Predicted closing price for 2024-09-01: $229.75
# Predicted closing price for 2024-09-02: $229.75
# Predicted closing price for 2024-09-03: $229.75
# Predicted closing price for 2024-09-04: $229.75
# Predicted closing price for 2024-09-05: $229.75
# Predicted closing price for 2024-09-06: $229.76
# Predicted closing price for 2024-09-07: $229.76
# Predicted closing price for 2024-09-08: $229.76
# Predicted closing price for 2024-09-09: $229.76
# Predicted closing price for 2024-09-10: $229.76
# Predicted closing price for 2024-09-11: $229.76
# Predicted closing price for 2024-09-12: $229.76
# Predicted closing price for 2024-09-13: $229.76
# Predicted closing price for 2024-09-14: $229.77
# Predicted closing price for 2024-09-15: $229.77
# Predicted closing price for 2024-09-16: $229.77
# Predicted closing price for 2024-09-17: $229.77
# Predicted closing price for 2024-09-18: $229.77
# Predicted closing price for 2024-09-19: $229.77
# Predicted closing price for 2024-09-20: $229.77
# Predicted closing price for 2024-09-21: $229.77
# Predicted closing price for 2024-09-22: $229.77
# Predicted closing price for 2024-09-23: $229.77
# Predicted closing price for 2024-09-24: $229.78
# Predicted closing price for 2024-09-25: $229.78
# Predicted closing price for 2024-09-26: $229.78
# Predicted closing price for 2024-09-27: $229.78
# Predicted closing price for 2024-09-28: $229.78
# Predicted closing price for 2024-09-29: $229.78
# Predicted closing price for 2024-09-30: $229.78
# Predicted closing price for 2024-10-01: $229.78
# Predicted closing price for 2024-10-02: $229.78
# Predicted closing price for 2024-10-03: $229.78
# Predicted closing price for 2024-10-04: $229.78
# Predicted closing price for 2024-10-05: $229.78
# Predicted closing price for 2024-10-06: $229.78
# Predicted closing price for 2024-10-07: $229.78
# Predicted closing price for 2024-10-08: $229.79
# Predicted closing price for 2024-10-09: $229.79
# Predicted closing price for 2024-10-10: $229.79
# Predicted closing price for 2024-10-11: $229.79
# Predicted closing price for 2024-10-12: $229.79
# Predicted closing price for 2024-10-13: $229.79
# Predicted closing price for 2024-10-14: $229.79
# Predicted closing price for 2024-10-15: $229.79
# Predicted closing price for 2024-10-16: $229.79
# Predicted closing price for 2024-10-17: $229.79
# Predicted closing price for 2024-10-18: $229.79
# Predicted closing price for 2024-10-19: $229.79
# Predicted closing price for 2024-10-20: $229.79
# Predicted closing price for 2024-10-21: $229.79
# Predicted closing price for 2024-10-22: $229.79
# Predicted closing price for 2024-10-23: $229.79
# Predicted closing price for 2024-10-24: $229.79
# Predicted closing price for 2024-10-25: $229.79
# Predicted closing price for 2024-10-26: $229.79
# Predicted closing price for 2024-10-27: $229.79
# Predicted closing price for 2024-10-28: $229.79
# Predicted closing price for 2024-10-29: $229.79
# Predicted closing price for 2024-10-30: $229.79
# Predicted closing price for 2024-10-31: $229.80
# Predicted closing price for 2024-11-01: $229.80
# Predicted closing price for 2024-11-02: $229.80
# Predicted closing price for 2024-11-03: $229.80
# Predicted closing price for 2024-11-04: $229.80
# Predicted closing price for 2024-11-05: $229.80
# Predicted closing price for 2024-11-06: $229.80
# Predicted closing price for 2024-11-07: $229.80

# %% [markdown]
# ### Visualize the Test Data and 365-Day Forecast

# %%
# Prepare the dates for forecasting by extending the existing dates array
forecast_dates = [df['Date'].iloc[-1] + pd.Timedelta(days=x + 1) for x in range(1, 366)]

plt.figure(figsize=(16, 8))
plt.title('Test Dataset and 365-Day Forecast')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

plt.plot(df['Date'][training_data_len:], y_test, label='Actual Values (Test)', color='Blue', alpha=0.3)
plt.plot(df['Date'][training_data_len:], test_predictions, label='Predicted Values (Test)', color='Green', alpha=0.9)
plt.plot(forecast_dates, predicted_prices, label='Forecasted Values', color='red', alpha=0.9)

plt.xticks(rotation=45)
plt.legend(loc='lower right')
plt.tight_layout()
plt.show()
